# %%
import pandas as pd

# %%
import numpy as np

# %%
#QUESTION 1
df = pd.read_csv('mower_market_snapshot.csv', delimiter=';') #Lire fichier CSV

# %%
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
#QUESTION 2
df.describe() #fonction describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
df.loc[:5] #fonction loc
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  817.085097  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  844.581465  141.48693796090603
# 5  19.548213      0.035428  18268  728.284617  905.297503  177.01288573033196
#
#   product_type quality warranty  market_share  attractiveness
# 0  auto-portee     Low     3ans      0.006360        0.650648
# 1  auto-portee     Low   3 ans.      0.006840        0.699792
# 2  auto-portee     Low    3_ans      0.006179        0.632129
# 3  auto-portee     Low   3 anss      0.007925        0.810730
# 4  auto-portee  Medium    3ans.      0.007406        0.757614
# ...

# %%
df.loc[2:5,('capacity','failure_rate','id')]
# Out:
#     capacity  failure_rate     id
# 2  20.190457      0.039111  19641
# 3  27.220131      0.041303  18728
# 4  16.370911      0.037938  18722
# 5  19.548213      0.035428  18268

# %%
df.sort_values(by='price', ascending=True).head() #fonction sort_values() + head()
# Out:
#        capacity  failure_rate     id      margin      price  \
# 535   43.410781      0.089094  19576  286.579692  62.162200
# 1052  50.843741      0.195125  18366   53.272369  62.855737
# 696   63.785109      0.228977  18315   55.156346  63.692980
# 710   55.682973      0.219791  18808   53.612922  63.984195
# 919   49.237933      0.232052  18290   55.214844  64.146445
#
#                prod_cost product_type quality warranty  market_share  \
# 535                    0   electrique     Low   2 anss      0.002389
# 1052   9.583368011630627      essence     Low    1 an.      0.001364
# 696    8.536633990796986      essence     Low    1 an.      0.001374
# 710   10.371273145783007      essence     Low     1 an      0.001545
# 919    8.931600382421172      essence     Low      1an      0.001269
#
#       attractiveness
# 535         0.622614
# 1052        0.719494
# 696         0.724895
# 710         0.815051
# 919         0.669645

# %%
df[df['id']==18259] #une vue != ...
# Out:
#        capacity  failure_rate     id     margin      price  \
# 1051  66.180234      0.249758  18259  61.182062  71.867486
#
#                prod_cost product_type quality warranty  market_share  \
# 1051  10.685424253813672      essence     Low    1 an.       0.00154
#
#       attractiveness
# 1051         0.81269

# %%
df.loc[df['id']==18259,:] #... une copie avec loc
# Out:
#        capacity  failure_rate     id     margin      price  \
# 1051  66.180234      0.249758  18259  61.182062  71.867486
#
#                prod_cost product_type quality warranty  market_share  \
# 1051  10.685424253813672      essence     Low    1 an.       0.00154
#
#       attractiveness
# 1051         0.81269

# %%
df[df['id'].isin([18259,18262])]
# Out:
#        capacity  failure_rate     id     margin      price  \
# 781    0.059048      0.241700  18262  58.573978  68.418652
# 1051  66.180234      0.249758  18259  61.182062  71.867486
#
#                prod_cost product_type quality warranty  market_share  \
# 781    9.844674524572053      essence     Low     1 an      0.001324
# 1051  10.685424253813672      essence     Low    1 an.      0.001540
#
#       attractiveness
# 781         0.698436
# 1051        0.812690

# %%
df.iloc[:5,:2] #fonction iloc
# Out:
#     capacity  failure_rate
# 0  10.492623      0.042528
# 1  20.273730      0.037896
# 2  20.190457      0.039111
# 3  27.220131      0.041303
# 4  16.370911      0.037938

# %%
df.dropna() #fonction dropana()
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df2 = df.copy() #Copie DataFrame
df2
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df2.drop_duplicates() # fonction drop_duplicates() 
df2 #Pas de doublons
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
pd.concat([df.head(),df2.head()])
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  817.085097  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  844.581465  141.48693796090603
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  817.085097  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  844.581465  141.48693796090603
#
#   product_type quality warranty  market_share  attractiveness
# ...

# %%
df.groupby('product_type').sum()
# Out:
#                   capacity  failure_rate        id         margin  \
# product_type
# auto-portee    2584.399203      5.321437   2701431   97115.734838
# electrique    15697.770195     39.609520   7829912  110199.284139
# essence       48398.740356    187.929728  15990899   53266.371298
#
#                       price  market_share  attractiveness
# product_type
# auto-portee   116631.583129           1.0      102.302514
# electrique    159033.286414           1.0      260.563075
# essence        88180.285829           1.0      527.607446

# %%
#QUESTION 3
df.groupby('prod_cost').sum()
# Out:
#                       capacity  failure_rate      id       margin  \
# prod_cost
# -64                 938.731080      3.051811  342132  3387.840282
# 0                   909.966696      3.416788  380220  3937.177892
# 10.000151312469615   73.070220      0.248440   18488    66.397478
# 10.002531748228646   47.548979      0.210551   19137    56.997519
# 10.008485830089475   64.469214      0.171804   18657    63.624150
# ...                        ...           ...     ...          ...
# 99.25351366885364    52.985916      0.094458   18550   262.216458
# 99.28924427491876    28.163433      0.081322   18409   263.467438
# 99.62971468653679    41.172818      0.094580   19521   254.211481
# 99.81312346726344    52.451596      0.083137   18708   254.872979
# unknown             615.673860      2.251474  244481  2308.169289
#
#                            price  market_share  attractiveness
# prod_cost
# -64                 10240.500750      0.036359       10.630728
# ...

# %%
df[df['prod_cost'].isin(['0','10.008485830089475'])]
# Out:
#        capacity  failure_rate     id      margin       price  \
# 47    25.136228      0.044026  19549  618.616295   69.359766
# 64    18.669448      0.036297  19368  738.279214  424.738557
# 126   12.417808      0.037797  19638  672.153234   74.156037
# 224   38.004822      0.088918  18523  255.289862   75.161299
# 377   42.216049      0.090275  18512  274.573188  877.008432
# 485   39.530576      0.098281  18731  266.559354  785.968557
# 535   43.410781      0.089094  19576  286.579692   62.162200
# 591   59.089766      0.198374  19065   66.589054  907.224715
# 632   53.057689      0.272022  19013   59.620476  746.037497
# 771   71.079908      0.204975  19084   64.761574  370.268763
# 803   64.469214      0.171804  18657   63.624150   73.632636
# 844   54.136865      0.212580  18956   58.926577  875.686141
# 873   73.951245      0.246320  18687   63.080659  882.868848
# 922   72.423733      0.261196  19336   68.353986  782.073365
# ...

# %%
#QUESTION 4
df.dropna().sum()
# Out:
# capacity                                               65801.907612
# failure_rate                                             229.864404
# id                                                         26180048
# margin                                                 257191.26206
# price                                                 354001.635745
# prod_cost         195.03551928211797151.31809934886763178.137319...
# product_type      auto-porteeauto-porteeauto-porteeauto-porteeau...
# quality           LowLowLowLowMediumMediumHightLowLowLowLowMediu...
# warranty          3ans3 ans.3_ans3 anss3ans.3 ans3_ans.3 anss3_a...
# market_share                                               2.959216
# attractiveness                                           878.549034
# dtype: object

# %%
# QUESTION 5
df.dropna(how= 'any').fillna(df.mean())
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
#QUESTION 6
df.iloc[:,8:9]
# Out:
#      warranty
# 0        3ans
# 1      3 ans.
# 2       3_ans
# 3      3 anss
# 4       3ans.
# ...       ...
# 1394     1 an
# 1395     1ans
# 1396     1an.
# 1397     1 an
# 1398     1an.
#
# [1399 rows x 1 columns]

# %%
#QUESTION 7
df['warranty'].shape
df['warranty'] = df['warranty'].str[0].astype(int)

# %%
df.iloc[:,8:9]
# Out:
#       warranty
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3
# ...        ...
# 1394         1
# 1395         1
# 1396         1
# 1397         1
# 1398         1
#
# [1399 rows x 1 columns]

# %%
#QUESTION 8
df['warranty'].unique()
# Out:
# array([3, 2, 1])

# %%
#QUESTION 9
def catPrice(price):
    if price <= 301:
        return '0-300'
    elif (price >= 300) & (price <= 500):
        return '301 - 500'
    elif price >= 501:
        return '500++'

df['price'] = df['price'].map(catPrice)

# %%
df.iloc[:,4:5]
# Out:
#       price
# 0     500++
# 1     500++
# 2     500++
# 3     500++
# 4     500++
# ...     ...
# 1394  0-300
# 1395  0-300
# 1396  500++
# 1397  0-300
# 1398  0-300
#
# [1399 rows x 1 columns]

# %%
#QUESTION 10
df.loc[df['product_type']=='auto-portee','product_type']=1
df.loc[df['product_type']=='electique','product_type']=2
df.loc[df['product_type']=='essence','product_type']=3
df["product_type"].unique()
# Out:
# array([1, 'electrique', 3], dtype=object)

# %%
df.iloc[:,6:7]
# Out:
#      product_type
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 1394            3
# 1395            3
# 1396            3
# 1397            3
# 1398            3
#
# [1399 rows x 1 columns]

# %%
#QUESTION 11
df=df.assign(isEssence=False)
df=df.assign(isElectrique=False)
df=df.assign(isAutoPortee=False)
df.loc[df['product_type']==1,'isAutoPortee']=True
df.loc[df['product_type']==2,'isElectrique']=True
df.loc[df['product_type']==3,'isEssence']=True

df.boolTypeColumns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-51137cfeb4df> in <module>
#       8     df.loc[df['product_type']==3,'isEssence']=True
#       9
# ---> 10 df.boolTypeColumns()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'boolTypeColumns'

# %%
df
# Out:
#        capacity  failure_rate     id      margin  price           prod_cost  \
# 0     10.492623      0.042528  18377  633.766584  500++  195.03551928211797
# 1     20.273730      0.037896  19363  731.576817  500++  151.31809934886763
# 2     20.190457      0.039111  19641  741.218202  500++  178.13731921134948
# 3     27.220131      0.041303  18728  654.255635  500++  162.82946157588628
# 4     16.370911      0.037938  18722  703.094527  500++  141.48693796090603
# ...         ...           ...    ...         ...    ...                 ...
# 1394  44.959895      0.234647  18451   63.662561  0-300  11.498540481074583
# 1395  59.356058      0.253694  18663   64.014543  0-300  11.380588736668567
# 1396  67.865222      0.228935  19169   62.132035  500++             unknown
# 1397  66.855435      0.244948  18946   58.697122  0-300   9.794196773761458
# 1398  54.712713      0.177143  19017   64.259212  0-300  10.696216086742934
#
# ...
